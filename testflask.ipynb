# %% [markdown]
# <a href="https://colab.research.google.com/github/Bloch-AI/BlochAI-PythonProgrammingforAI/blob/master/testflask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.output import eval_js
eval_js("google.colab.kernel.proxyPort(5000)")

print('Upload Jinja template')
from google.colab import files
uploaded = files.upload()

# Get the actual file name with the unique identifier
for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))

# !pip install flask-ngrok
# !ngrok authtoken 'INSERT TOKEN'
import os
import shutil

# Create templates folder if it doesn't exist
if not os.path.exists('templates'):
    os.makedirs('templates')

# Move the uploaded file into templates folder using the actual file name
source = fn
destination = os.path.join('templates', fn)
shutil.move(source, destination)

from flask import Flask, render_template, request
import pickle
from pyngrok import ngrok

# Upload the model
print('Upload pickle model file')
uploaded_model = files.upload()  # Upload the 'model.pkl' file

# Get the actual filename with identifier
for model_filename in uploaded_model.keys():
    print('User uploaded model file "{name}" with length {length} bytes'.format(
        name=model_filename, length=len(uploaded_model[model_filename])))

ngrok.set_auth_token("2txQUnd8tYTekpMOPuvOgc9ezS9_4gvNGUXZZEZRwhoufnyyx")

# Open a ngrok tunnel to the default port 5000
public_url = ngrok.connect(5000).public_url
print(f"Your app is accessible at: {public_url}")

app= Flask(__name__)
# Assuming the uploaded model file is 'model.pkl'
model = pickle.load(open(model_filename, 'rb'))

@app.route("/")
def web_page_gen ():
    return render_template(fn)

@app.route("/predict", methods =['POST'])
def predict():
    Practice1 = int(request.form['Practice 1'])
    Practice2 = int(request.form['Practice 2'])
    prediction = model.predict([[Practice1, Practice2]])
    output = round(prediction[0])
    return render_template(fn,
                            answer = f'Scores of {Practice1} and {Practice2} in the practice test \
                                indicate a score of {output} in the final test')

if __name__ == "__main__":
    app.run()
# Out:
# Upload Jinja template
#      <input type="file" id="files-b14904a4-7046-4832-8173-c77ad0066677" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b14904a4-7046-4832-8173-c77ad0066677">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
